# %% [markdown]
# # Loading in the Data
# In this example, we are going to use crossed columns and embedding columns inside of a tensorflow object created with keras.
#
# However, we will start the process by loading up a dataset with a mix of categorical data and numeric data. This dataset is quite old and has been used many times in machine learning examples: the census data from 1990's. We will use it to predict if a person will earn over or under 50k per year.
#
# - https://archive.ics.uci.edu/ml/datasets/Census-Income+(KDD)
# - This data goes by various name, including the "Adult" dataset and 1996 census data

# %%
import pandas as pd

headers = ['age','workclass','fnlwgt','education','edu_num','marital_status',
           'occupation','relationship','race','sex','cap_gain','cap_loss','work_hrs_weekly','country','income']
df_train_orig = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',names=headers)
df_test_orig = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test',names=headers)
df_test_orig = df_test_orig.iloc[1:]
print(df_train_orig.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              32561 non-null  int64
#  1   workclass        32561 non-null  object
#  2   fnlwgt           32561 non-null  int64
#  3   education        32561 non-null  object
#  4   edu_num          32561 non-null  int64
#  5   marital_status   32561 non-null  object
#  6   occupation       32561 non-null  object
#  7   relationship     32561 non-null  object
#  8   race             32561 non-null  object
#  9   sex              32561 non-null  object
#  10  cap_gain         32561 non-null  int64
#  11  cap_loss         32561 non-null  int64
#  12  work_hrs_weekly  32561 non-null  int64
#  13  country          32561 non-null  object
#  14  income           32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None

# %%
from copy import deepcopy
df_train = deepcopy(df_train_orig)
df_test = deepcopy(df_test_orig)

# %% [markdown]
# The data is organized as follows:
#
# |Variable | description|
# |----|--------|
# |age: | continuous|
# |workclass:      |Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, ...|
# |fnlwgt:         |continuous.|
# |education:      |Bachelors, Some-college, 11th, HS-grad, Prof-school, ...|
# |education-num:  |continuous.|
# |marital-status: |Married-civ-spouse, Divorced, Never-married, Separated, Widowed, ... |
# |occupation:     |Tech-support, Craft-repair, Other-service, ...|
# |relationship:   | Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.|
# |race:           |White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.|
# |sex:            |Female, Male.|
# |capital-gain:   |continuous.|
# |capital-loss:   |continuous.|
# |hours-per-week: |continuous.|
# |native-country: |United-States, Cambodia, England, ... |
# |**income (target):**|<50k, >=50k|

# %%
import numpy as np

# let's just get rid of rows with any missing data
# and then reset the indices of the dataframe so it corresponds to row number
df_train.replace(to_replace=' ?',value=np.nan, inplace=True)
df_train.dropna(inplace=True)
df_train.reset_index()

df_test.replace(to_replace=' ?',value=np.nan, inplace=True)
df_test.dropna(inplace=True)
df_test.reset_index()

df_test.head()
# Out:
#   age   workclass    fnlwgt      education  edu_num       marital_status  \
# 1  25     Private  226802.0           11th      7.0        Never-married
# 2  38     Private   89814.0        HS-grad      9.0   Married-civ-spouse
# 3  28   Local-gov  336951.0     Assoc-acdm     12.0   Married-civ-spouse
# 4  44     Private  160323.0   Some-college     10.0   Married-civ-spouse
# 6  34     Private  198693.0           10th      6.0        Never-married
#
#            occupation    relationship    race    sex  cap_gain  cap_loss  \
# 1   Machine-op-inspct       Own-child   Black   Male       0.0       0.0
# 2     Farming-fishing         Husband   White   Male       0.0       0.0
# 3     Protective-serv         Husband   White   Male       0.0       0.0
# 4   Machine-op-inspct         Husband   Black   Male    7688.0       0.0
# 6       Other-service   Not-in-family   White   Male       0.0       0.0
#
#    work_hrs_weekly         country   income
# 1             40.0   United-States   <=50K.
# 2             50.0   United-States   <=50K.
# 3             40.0   United-States    >50K.
# 4             40.0   United-States    >50K.
# 6             30.0   United-States   <=50K.

# %% [markdown]
# ## Processing
# For preprocessing, we are going to fix a few issues in the dataset.
#
# - This first includes the use of "50K." instead of "50K" in the test set.
# - Next, we will encode the categorical features as integers (eventually we will deal with these integers like a one-hot encoding)
# - Finally, we will make certain all the continuous data is scaled properly with zero mean and unit standard deviaiton

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# replace strings
if df_test.income.dtype=='object':
    df_test.income.replace(to_replace=[' <=50K.',' >50K.'],value=['<=50K','>50K'],inplace=True)
    print(df_test.income.value_counts())

# define objects that can encode each variable as integer    
encoders = dict() 
categorical_headers = ['workclass','education','marital_status',
                       'occupation','relationship','race','sex','country']

# train all encoders (special case the target 'income')
for col in categorical_headers+['income']:
    df_train[col] = df_train[col].str.strip()
    df_test[col] = df_test[col].str.strip()
    
    if col=="income":
        tmp = LabelEncoder()
        df_train[col] = tmp.fit_transform(df_train[col])
        df_test[col] = tmp.transform(df_test[col])
    else:
        # integer encoded variables
        encoders[col] = LabelEncoder() # save the encoder
        df_train[col+'_int'] = encoders[col].fit_transform(df_train[col])
        df_test[col+'_int'] = encoders[col].transform(df_test[col])

# scale the numeric, continuous variables
numeric_headers = ["age", "cap_gain", "cap_loss","work_hrs_weekly"]

for col in numeric_headers:
    df_train[col] = df_train[col].astype(np.float)
    df_test[col] = df_test[col].astype(np.float)
    
    ss = StandardScaler()
    df_train[col] = ss.fit_transform(df_train[col].values.reshape(-1, 1))
    df_test[col] = ss.transform(df_test[col].values.reshape(-1, 1))
    
df_test.head()
# Out:
# <=50K    11360
# >50K      3700
# Name: income, dtype: int64
#         age  workclass    fnlwgt     education  edu_num      marital_status  \
# 1 -1.023104    Private  226802.0          11th      7.0       Never-married
# 2 -0.033340    Private   89814.0       HS-grad      9.0  Married-civ-spouse
# 3 -0.794697  Local-gov  336951.0    Assoc-acdm     12.0  Married-civ-spouse
# 4  0.423474    Private  160323.0  Some-college     10.0  Married-civ-spouse
# 6 -0.337883    Private  198693.0          10th      6.0       Never-married
#
#           occupation   relationship   race   sex  ...        country  income  \
# 1  Machine-op-inspct      Own-child  Black  Male  ...  United-States       0
# 2    Farming-fishing        Husband  White  Male  ...  United-States       0
# 3    Protective-serv        Husband  White  Male  ...  United-States       1
# 4  Machine-op-inspct        Husband  Black  Male  ...  United-States       1
# 6      Other-service  Not-in-family  White  Male  ...  United-States       0
#
#    workclass_int education_int  marital_status_int  occupation_int  \
# 1              2             1                   4               6
# 2              2            11                   2               4
# 3              1             7                   2              10
# 4              2            15                   2               6
# 6              2             0                   4               7
#
#    relationship_int  race_int  sex_int  country_int
# 1                 3         2        1           38
# 2                 0         4        1           38
# 3                 0         4        1           38
# 4                 0         2        1           38
# 6                 1         4        1           38
#
# [5 rows x 23 columns]

# %%
df_train['income']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: income, Length: 30162, dtype: int32

# %%
# let's start as simply as possible, without any feature preprocessing
categorical_headers_ints = [x+'_int' for x in categorical_headers]

# we will forego one-hot encoding right now and instead just scale all inputs
#   this is just to get an example running in Keras (don't ever do this)
feature_columns = categorical_headers_ints+numeric_headers
X_train =  ss.fit_transform(df_train[feature_columns].values).astype(np.float32)
X_test =  ss.transform(df_test[feature_columns].values).astype(np.float32)

y_train = df_train['income'].values.astype(np.int)
y_test = df_test['income'].values.astype(np.int)

print(feature_columns)
# Out:
# ['workclass_int', 'education_int', 'marital_status_int', 'occupation_int', 'relationship_int', 'race_int', 'sex_int', 'country_int', 'age', 'cap_gain', 'cap_loss', 'work_hrs_weekly']

# %% [markdown]
# ![keras](https://blog.keras.io/img/keras-tensorflow-logo.jpg)
#
#
# # An example similar to Sklearn, Keras
# - We will start with creating a model that is similar to what we have already written.
# - Let's not worry about pre-processing the data right now. Let's just get familiar with Keras.

# %%
from sklearn import metrics as mt
from tensorflow import keras

keras.__version__
# Out:
# '2.4.0'

# %%
from tensorflow.keras.layers import Dense, Activation, Input
from tensorflow.keras.layers import Embedding, Flatten, Concatenate
from tensorflow.keras.models import Model

# %%
# combine the features into a single large matrix
X_train = df_train[feature_columns].to_numpy()
X_test = df_test[feature_columns].to_numpy()

# Now let's define the architecture for a multi-layer network

# First, lets setup the input size
num_features = X_train.shape[1]
input_tensor = Input(shape=(num_features,))

# a layer instance is callable on a tensor, and returns a tensor
x = Dense(units=10, activation='relu')(input_tensor)
x = Dense(units=5, activation='tanh')(x)
predictions = Dense(1,activation='sigmoid')(x)

# This creates a model that includes
# the Input layer and three Dense layers
model = Model(inputs=input_tensor, outputs=predictions)

# %% [markdown]
# ___
# ## Adding more customization
# For this particular optimization, we could go beyond SGD and use a different optimizer. There are many excellent explanations of different optimizers, for instance:
# - http://sebastianruder.com/optimizing-gradient-descent/
#
# Now that we have defined the model, its as simple as using it in a very familiar syntax:

# %%
model.compile(optimizer='sgd',
              loss='mean_squared_error',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "functional_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 12)]              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                130
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 55
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 191
# Trainable params: 191
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

# you will need to install pydot properly on your machine to get this running
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
# %%time

model.fit(X_train, y_train, epochs=10, batch_size=50, verbose=1)

# now lets see how well the model performed
from sklearn import metrics as mt
yhat_proba = model.predict(X_test)
yhat = np.round(yhat_proba)
print(mt.confusion_matrix(y_test,yhat))
print(mt.classification_report(y_test,yhat))
# Out:
# Epoch 1/10
# 604/604 [==============================] - 0s 447us/step - loss: 0.2101 - accuracy: 0.6832
# Epoch 2/10
# 604/604 [==============================] - 0s 452us/step - loss: 0.1809 - accuracy: 0.7506
# Epoch 3/10
# 604/604 [==============================] - 0s 450us/step - loss: 0.1774 - accuracy: 0.7508
# Epoch 4/10
# 604/604 [==============================] - 0s 452us/step - loss: 0.1732 - accuracy: 0.7506
# Epoch 5/10
# 604/604 [==============================] - 0s 444us/step - loss: 0.1688 - accuracy: 0.7504
# Epoch 6/10
# 604/604 [==============================] - 0s 449us/step - loss: 0.1646 - accuracy: 0.7501
# Epoch 7/10
# 604/604 [==============================] - 0s 444us/step - loss: 0.1609 - accuracy: 0.7500
# Epoch 8/10
# 604/604 [==============================] - 0s 437us/step - loss: 0.1574 - accuracy: 0.7515
# Epoch 9/10
# 604/604 [==============================] - 0s 452us/step - loss: 0.1542 - accuracy: 0.7682
# Epoch 10/10
# 604/604 [==============================] - 0s 457us/step - loss: 0.1514 - accuracy: 0.7783
# [[10938   422]
#  [ 2953   747]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.96      0.87     11360
#            1       0.64      0.20      0.31      3700
#
#     accuracy                           0.78     15060
#    macro avg       0.71      0.58      0.59     15060
# weighted avg       0.75      0.78      0.73     15060
#
# Wall time: 3.27 s

# %% [markdown]
# Ouch! It didn't even train! **But we are not handling categorical data properly here...** Let's fix that.
#
# ## Embedding Categorical Data
# In order to add one-hot encoding, we need to separate the categorical features that are currently saved as integers and place them into Embedding layers. An embedding layer deals with integers as if they were one-hot encoded. To start, let's only create a model from these categorical variables.
#
# - The first decision to make is about the size of the dense feature embeddings. This is essentially a dimensionality reduction step.
#  - This can be difficult to set, but one common setting is $\log_2(N)$ or $\sqrt{N}$ where $N$ is the total number of uniques values.
# - When using an Embedding, we can leave the variables represented as integers. That is, keras will use the integer representation to figure out how to one-hot-encode the variable. This is great because it means we don't need to change the variable in memory.
# - We will feed all the categorical variables to the model and, internally, the model will separate out the columns and apply a separate embedding. The function we will use to get each column is the `gather` function that is part of tensorflow.

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import concatenate
import tensorflow as tf

# start by getting only the categorical variables
# these matrices are all integers
X_train = df_train[categorical_headers_ints].to_numpy() 
X_test = df_test[categorical_headers_ints].to_numpy() 

embed_branches = []
all_branch_outputs = [] # this is where we will keep track of output of each branch

# feed in the entire matrix of categircal variables
input_branch = Input(shape=(X_train.shape[1],), 
                     dtype='int64', 
                     name='categorical')

# for each categorical variable
for idx,col in enumerate(categorical_headers_ints):
    
    # what the maximum integer value for this variable?
    # which is the same as the number of categories
    N = max(df_train[col].max(),df_test[col].max())+1 
    
    # this line of code does this: input_branch[:,idx]
    x = tf.gather(input_branch, idx, axis=1)
    
    # now use an embedding to deal with integers as if they were one hot encoded
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name=col+'_embed')(x)
    
    # save these outputs in list to concatenate later
    all_branch_outputs.append(x)
    
# now concatenate the outputs and add a fully connected layer
final_branch = concatenate(all_branch_outputs, name='concat_1')
final_branch = Dense(units=1,
                     activation='sigmoid', 
                     name='combined')(final_branch)

model = Model(inputs=input_branch, outputs=final_branch)

model.compile(optimizer='sgd',
              loss='mean_squared_error',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "functional_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# categorical (InputLayer)        [(None, 8)]          0
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_30 (Tensor [(None,)]            0           categorical[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_31 (Tensor [(None,)]            0           categorical[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_32 (Tensor [(None,)]            0           categorical[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_33 (Tensor [(None,)]            0           categorical[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_34 (Tensor [(None,)]            0           categorical[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_35 (Tensor [(None,)]            0           categorical[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_36 (Tensor [(None,)]            0           categorical[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_37 (Tensor [(None,)]            0           categorical[0][0]
# __________________________________________________________________________________________________
# workclass_int_embed (Embedding) (None, 2)            14          tf_op_layer_GatherV2_30[0][0]
# __________________________________________________________________________________________________
# education_int_embed (Embedding) (None, 4)            64          tf_op_layer_GatherV2_31[0][0]
# __________________________________________________________________________________________________
# marital_status_int_embed (Embed (None, 2)            14          tf_op_layer_GatherV2_32[0][0]
# __________________________________________________________________________________________________
# occupation_int_embed (Embedding (None, 3)            42          tf_op_layer_GatherV2_33[0][0]
# __________________________________________________________________________________________________
# relationship_int_embed (Embeddi (None, 2)            12          tf_op_layer_GatherV2_34[0][0]
# __________________________________________________________________________________________________
# race_int_embed (Embedding)      (None, 2)            10          tf_op_layer_GatherV2_35[0][0]
# __________________________________________________________________________________________________
# sex_int_embed (Embedding)       (None, 1)            2           tf_op_layer_GatherV2_36[0][0]
# __________________________________________________________________________________________________
# country_int_embed (Embedding)   (None, 6)            246         tf_op_layer_GatherV2_37[0][0]
# __________________________________________________________________________________________________
# concat_1 (Concatenate)          (None, 22)           0           workclass_int_embed[0][0]
#                                                                  education_int_embed[0][0]
#                                                                  marital_status_int_embed[0][0]
#                                                                  occupation_int_embed[0][0]
#                                                                  relationship_int_embed[0][0]
#                                                                  race_int_embed[0][0]
#                                                                  sex_int_embed[0][0]
#                                                                  country_int_embed[0][0]
# __________________________________________________________________________________________________
# combined (Dense)                (None, 1)            23          concat_1[0][0]
# ==================================================================================================
# Total params: 427
# Trainable params: 427
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
X_train
# Out:
# array([[ 5,  9,  4, ...,  4,  1, 38],
#        [ 4,  9,  2, ...,  4,  1, 38],
#        [ 2, 11,  0, ...,  4,  1, 38],
#        ...,
#        [ 2, 11,  6, ...,  4,  0, 38],
#        [ 2, 11,  4, ...,  4,  1, 38],
#        [ 3, 11,  2, ...,  4,  0, 38]])

# %%
# %%time

model.fit(X_train, y_train, epochs=10, batch_size=50, verbose=1)

from sklearn import metrics as mt
yhat_proba = model.predict(X_test)
yhat = np.round(yhat_proba)
print(mt.confusion_matrix(y_test,yhat))
print(mt.classification_report(y_test,yhat))
# Out:
# Epoch 1/10
# 604/604 [==============================] - 0s 495us/step - loss: 0.2093 - accuracy: 0.7358
# Epoch 2/10
# 604/604 [==============================] - 0s 498us/step - loss: 0.1833 - accuracy: 0.7511
# Epoch 3/10
# 604/604 [==============================] - 0s 493us/step - loss: 0.1760 - accuracy: 0.7511
# Epoch 4/10
# 604/604 [==============================] - 0s 485us/step - loss: 0.1695 - accuracy: 0.7511
# Epoch 5/10
# 604/604 [==============================] - 0s 508us/step - loss: 0.1628 - accuracy: 0.7511
# Epoch 6/10
# 604/604 [==============================] - 0s 558us/step - loss: 0.1566 - accuracy: 0.7522
# Epoch 7/10
# 604/604 [==============================] - 0s 537us/step - loss: 0.1514 - accuracy: 0.7547
# Epoch 8/10
# 604/604 [==============================] - 0s 535us/step - loss: 0.1474 - accuracy: 0.7709
# Epoch 9/10
# 604/604 [==============================] - 0s 504us/step - loss: 0.1443 - accuracy: 0.7949
# Epoch 10/10
# 604/604 [==============================] - 0s 561us/step - loss: 0.1418 - accuracy: 0.8029
# [[10872   488]
#  [ 2474  1226]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.96      0.88     11360
#            1       0.72      0.33      0.45      3700
#
#     accuracy                           0.80     15060
#    macro avg       0.76      0.64      0.67     15060
# weighted avg       0.79      0.80      0.78     15060
#
# Wall time: 4.17 s

# %% [markdown]
# Much better!! Looks like the use of Embedding layers helped. Lets add some more of the features, useing both the categorical and the integer features.
#
# ## Multi-Modal Networks: Combine Branches, Sparse and Dense
# The keras functional API allows us to setup different branches of inputs. When we call the `fit` function, we can tell keras the input to each branch using a simple list (you can also use a dictionary to be more explicit).
#
# - Lets create two matrics:
#  - one with the categorical data, `X_train_cat`
#  - and another with the numeric data, `X_train_num`
#
# Now, we can feed both of these into the model as a list and concatenate their results.

# %%
# save categorical features
X_train_cat = df_train[categorical_headers_ints].to_numpy() 
X_test_cat = df_test[categorical_headers_ints].to_numpy() 

# and save off the numeric features
X_train_num =  df_train[numeric_headers].to_numpy()
X_test_num = df_test[numeric_headers].to_numpy()

all_branch_outputs = [] # this is where we will keep track of output of each branch

input_cat = Input(shape=(X_train_cat.shape[1],), dtype='int64', name='categorical')
for idx,col in enumerate(categorical_headers_ints):
    
    # track what the maximum integer value will be for this variable
    # which is the same as the number of categories
    N = max(df_train[col].max(),df_test[col].max())+1
    
    
    # this line of code does this: input_branch[:,idx]
    x = tf.gather(input_cat, idx, axis=1)
    
    # now use an embedding to deal with integers as if they were one hot encoded
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name=col+'_embed')(x)
    
    # save these outputs to concatenate later
    all_branch_outputs.append(x)
    
# HERE IS THE ADDING OF AN INPUT USING NUMERIC DATA
# create dense input branch for numeric
inputs_num = Input(shape=(X_train_num.shape[1],), name='numeric')
x_dense = Dense(units=15, activation='relu',name='num_1')(inputs_num)
    
all_branch_outputs.append(x_dense)

# now concatenate the outputs and add a fully connected layer
final_branch = concatenate(all_branch_outputs, name='concat_1')
final_branch = Dense(units=1,activation='sigmoid', name='combined')(final_branch)

model = Model(inputs=[input_cat,inputs_num], outputs=final_branch)

model.compile(optimizer='sgd',
              loss='mean_squared_error',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "functional_15"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# categorical (InputLayer)        [(None, 8)]          0
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_38 (Tensor [(None,)]            0           categorical[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_39 (Tensor [(None,)]            0           categorical[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_40 (Tensor [(None,)]            0           categorical[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_41 (Tensor [(None,)]            0           categorical[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_42 (Tensor [(None,)]            0           categorical[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_43 (Tensor [(None,)]            0           categorical[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_44 (Tensor [(None,)]            0           categorical[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_45 (Tensor [(None,)]            0           categorical[0][0]
# __________________________________________________________________________________________________
# numeric (InputLayer)            [(None, 4)]          0
# __________________________________________________________________________________________________
# workclass_int_embed (Embedding) (None, 2)            14          tf_op_layer_GatherV2_38[0][0]
# __________________________________________________________________________________________________
# education_int_embed (Embedding) (None, 4)            64          tf_op_layer_GatherV2_39[0][0]
# __________________________________________________________________________________________________
# marital_status_int_embed (Embed (None, 2)            14          tf_op_layer_GatherV2_40[0][0]
# __________________________________________________________________________________________________
# occupation_int_embed (Embedding (None, 3)            42          tf_op_layer_GatherV2_41[0][0]
# __________________________________________________________________________________________________
# relationship_int_embed (Embeddi (None, 2)            12          tf_op_layer_GatherV2_42[0][0]
# __________________________________________________________________________________________________
# race_int_embed (Embedding)      (None, 2)            10          tf_op_layer_GatherV2_43[0][0]
# __________________________________________________________________________________________________
# sex_int_embed (Embedding)       (None, 1)            2           tf_op_layer_GatherV2_44[0][0]
# __________________________________________________________________________________________________
# country_int_embed (Embedding)   (None, 6)            246         tf_op_layer_GatherV2_45[0][0]
# __________________________________________________________________________________________________
# num_1 (Dense)                   (None, 15)           75          numeric[0][0]
# __________________________________________________________________________________________________
# concat_1 (Concatenate)          (None, 37)           0           workclass_int_embed[0][0]
#                                                                  education_int_embed[0][0]
#                                                                  marital_status_int_embed[0][0]
#                                                                  occupation_int_embed[0][0]
#                                                                  relationship_int_embed[0][0]
#                                                                  race_int_embed[0][0]
#                                                                  sex_int_embed[0][0]
#                                                                  country_int_embed[0][0]
#                                                                  num_1[0][0]
# __________________________________________________________________________________________________
# combined (Dense)                (None, 1)            38          concat_1[0][0]
# ==================================================================================================
# Total params: 517
# Trainable params: 517
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
# %%time

model.compile(optimizer='sgd',
              loss='mean_squared_error',
              metrics=['accuracy'])

model.fit([ X_train_cat, X_train_num ], # inputs for each branch are a list
          y_train, 
          epochs=10, 
          batch_size=50, 
          verbose=1)

yhat = model.predict([X_test_cat,
                      X_test_num]) # each branch has an input

yhat = np.round(yhat)
print(mt.confusion_matrix(y_test,yhat))
print(mt.classification_report(y_test,yhat))
# Out:
# Epoch 1/10
# 604/604 [==============================] - 0s 545us/step - loss: 0.1969 - accuracy: 0.7472
# Epoch 2/10
# 604/604 [==============================] - 0s 542us/step - loss: 0.1761 - accuracy: 0.7511
# Epoch 3/10
# 604/604 [==============================] - 0s 552us/step - loss: 0.1657 - accuracy: 0.7526
# Epoch 4/10
# 604/604 [==============================] - 0s 528us/step - loss: 0.1542 - accuracy: 0.7692
# Epoch 5/10
# 604/604 [==============================] - 0s 528us/step - loss: 0.1479 - accuracy: 0.7803
# Epoch 6/10
# 604/604 [==============================] - 0s 565us/step - loss: 0.1439 - accuracy: 0.7878
# Epoch 7/10
# 604/604 [==============================] - 0s 545us/step - loss: 0.1402 - accuracy: 0.7932
# Epoch 8/10
# 604/604 [==============================] - 0s 542us/step - loss: 0.1367 - accuracy: 0.7994
# Epoch 9/10
# 604/604 [==============================] - 0s 560us/step - loss: 0.1334 - accuracy: 0.8068
# Epoch 10/10
# 604/604 [==============================] - 0s 535us/step - loss: 0.1303 - accuracy: 0.8125
# [[10957   403]
#  [ 2378  1322]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.96      0.89     11360
#            1       0.77      0.36      0.49      3700
#
#     accuracy                           0.82     15060
#    macro avg       0.79      0.66      0.69     15060
# weighted avg       0.81      0.82      0.79     15060
#
# Wall time: 4.42 s

# %% [markdown]
# So the confusion matrix is doing pretty well! But we still are just using a simple neural network. We really want to take advantage of the embeddings and crossed columns that are possible with tensorflow.
#
#
# **[Back to Slides]**
# ___

# %% [markdown]
# # Crossed Columns and Deep Embeddings
# Lets create the network below in steps. This network consists of a number of different paths for the input data to take.
# ![asdfasfd](https://www.tensorflow.org/images/wide_n_deep.svg)

# %% [markdown]
# ___
#
#
# ## Making Crossed Columns
# For this example, we are going to make embeddings for crossed columns. We will perform this step using `sklearn`
#
# Let's start simple with
# - branches of crossed categorical features as input
# - one branch for each crossed column

# %%
df_train
# Out:
#             age         workclass  fnlwgt   education  edu_num  \
# 0      0.042796         State-gov   77516   Bachelors       13
# 1      0.880288  Self-emp-not-inc   83311   Bachelors       13
# 2     -0.033340           Private  215646     HS-grad        9
# 3      1.108695           Private  234721        11th        7
# 4     -0.794697           Private  338409   Bachelors       13
# ...         ...               ...     ...         ...      ...
# 32556 -0.870832           Private  257302  Assoc-acdm       12
# 32557  0.118931           Private  154374     HS-grad        9
# 32558  1.489374           Private  151910     HS-grad        9
# 32559 -1.251511           Private  201490     HS-grad        9
# 32560  1.032559      Self-emp-inc  287927     HS-grad        9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical      Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        ...        country  income  workclass_int education_int  \
# 0      ...  United-States       0              5             9
# 1      ...  United-States       0              4             9
# 2      ...  United-States       0              2            11
# 3      ...  United-States       0              2             1
# 4      ...           Cuba       0              2             9
# ...    ...            ...     ...            ...           ...
# 32556  ...  United-States       0              2             7
# 32557  ...  United-States       1              2            11
# 32558  ...  United-States       0              2            11
# 32559  ...  United-States       0              2            11
# 32560  ...  United-States       1              3            11
#
#        marital_status_int  occupation_int  relationship_int  race_int  \
# 0                       4               0                 1         4
# 1                       2               3                 0         4
# 2                       0               5                 1         4
# 3                       2               5                 0         2
# 4                       2               9                 5         2
# ...                   ...             ...               ...       ...
# 32556                   2              12                 5         4
# 32557                   2               6                 0         4
# 32558                   6               0                 4         4
# 32559                   4               0                 3         4
# 32560                   2               3                 5         4
#
#        sex_int  country_int
# 0            1           38
# 1            1           38
# 2            1           38
# 3            1           38
# 4            0            4
# ...        ...          ...
# 32556        0           38
# 32557        1           38
# 32558        0           38
# 32559        1           38
# 32560        0           38
#
# [30162 rows x 23 columns]

# %%
# possible crossing options:
#   'workclass','education','marital_status',
#   'occupation','relationship','race',
#   'sex','country'

cross_columns = [['sex','education','occupation'],
                 #['sex', 'marital_status'],
                 ['workclass','occupation'],
                 ['occupation','race']
                ]

# cross each set of columns in the list above
cross_col_df_names = []
for cols_list in cross_columns:
    # encode as ints for the embedding
    enc = LabelEncoder()
    
    # 1. create crossed labels by join operation
    X_crossed_train = df_train[cols_list].apply(lambda x: '_'.join(x), axis=1)
    X_crossed_test = df_test[cols_list].apply(lambda x: '_'.join(x), axis=1)
    
    # get a nice name for this new crossed column
    cross_col_name = '_'.join(cols_list)
    
    # 2. encode as integers
    enc.fit(np.hstack((X_crossed_train.to_numpy(),  X_crossed_test.to_numpy())))
    
    # 3. Save into dataframe with new name
    df_train[cross_col_name] = enc.transform(X_crossed_train)
    df_test[cross_col_name] = enc.transform(X_crossed_test)
    
    # keep track of the new names of the crossed columns
    cross_col_df_names.append(cross_col_name)

# %%
y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
# get crossed columns
X_train_crossed = df_train[cross_col_df_names].to_numpy()
X_test_crossed = df_test[cross_col_df_names].to_numpy()

crossed_outputs = [] # this is where we will keep track of output of each branch

input_crossed = Input(shape=(X_train_crossed.shape[1],), dtype='int64', name='categorical')
for idx,col in enumerate(cross_col_df_names):
    
    # track what the maximum integer value will be for this variable
    # which is the same as the number of categories
    N = max(df_train[col].max(),df_test[col].max())+1
    
    # this line of code does this: input_branch[:,idx]
    x = tf.gather(input_crossed, idx, axis=1)
    
    # now use an embedding to deal with integers as if they were one hot encoded
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name=col+'_embed')(x)
    
    # save these outputs to concatenate later
    crossed_outputs.append(x)
    

# now concatenate the outputs and add a fully connected layer
wide_branch = concatenate(crossed_outputs, name='concat_1')
wide_branch = Dense(units=1,activation='sigmoid', name='combined')(wide_branch)

model = Model(inputs=input_crossed, outputs=wide_branch)

model.compile(optimizer='sgd',
              loss='mean_squared_error',
              metrics=['accuracy'])

model.fit(X_train_crossed,
        y_train, epochs=10, batch_size=32, verbose=1)
# Out:
# Epoch 1/10
# 943/943 [==============================] - 0s 449us/step - loss: 0.2094 - accuracy: 0.7473
# Epoch 2/10
# 943/943 [==============================] - 0s 453us/step - loss: 0.1864 - accuracy: 0.7511
# Epoch 3/10
# 943/943 [==============================] - 0s 451us/step - loss: 0.1817 - accuracy: 0.7511
# Epoch 4/10
# 943/943 [==============================] - 0s 453us/step - loss: 0.1789 - accuracy: 0.7511
# Epoch 5/10
# 943/943 [==============================] - 0s 450us/step - loss: 0.1763 - accuracy: 0.7511
# Epoch 6/10
# 943/943 [==============================] - 0s 457us/step - loss: 0.1735 - accuracy: 0.7511
# Epoch 7/10
# 943/943 [==============================] - 0s 453us/step - loss: 0.1708 - accuracy: 0.7511
# Epoch 8/10
# 943/943 [==============================] - 0s 448us/step - loss: 0.1682 - accuracy: 0.7511
# Epoch 9/10
# 943/943 [==============================] - 0s 453us/step - loss: 0.1659 - accuracy: 0.7555
# Epoch 10/10
# 943/943 [==============================] - 0s 450us/step - loss: 0.1638 - accuracy: 0.7611

# %%
yhat = np.round(model.predict(X_test_crossed))
print(mt.confusion_matrix(y_test,yhat))
print(mt.classification_report(y_test,yhat))
# Out:
# [[11159   201]
#  [ 3338   362]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.98      0.86     11360
#            1       0.64      0.10      0.17      3700
#
#     accuracy                           0.77     15060
#    macro avg       0.71      0.54      0.52     15060
# weighted avg       0.74      0.77      0.69     15060

# %%
# you will need to install pydot properly on your machine to get this running
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %% [markdown]
# Wow! That is just using crossed columns and a one layer Linear Classifer! So memorization works fairly well here.

# %% [markdown]
# ___
#
#
# ## Combining Crossed Linear Classifier and Deep Embeddings
# Now its just a matter of setting the wide and deep columns for tensorflow. After which, we can use the combined classifier!
#
# Wide and deep models can have really interesting and useful properties so they are great to keep in mind when selecting an architecture. Some of the hyperparameters that are specific to this are:
# - which features to cross together, typically you only want to cross columns you think are important to be connected--they somehow might create new knowledge by combining.
# - the size of the dense feature embeddings. This can be difficult to set, but one common setting is $log_2(N)$ or $\sqrt{N}$ where $N$ is the total number of uniques values.

# %%
# get crossed columns
X_train_crossed = df_train[cross_col_df_names].to_numpy()
X_test_crossed = df_test[cross_col_df_names].to_numpy()

# save categorical features
X_train_cat = df_train[categorical_headers_ints].to_numpy() 
X_test_cat = df_test[categorical_headers_ints].to_numpy() 

# and save off the numeric features
X_train_num =  df_train[numeric_headers].to_numpy()
X_test_num = df_test[numeric_headers].to_numpy()


# we need to create separate lists for each branch
crossed_outputs = []

# CROSSED DATA INPUT
input_crossed = Input(shape=(X_train_crossed.shape[1],), dtype='int64', name='wide_inputs')
for idx,col in enumerate(cross_col_df_names):
    
    # track what the maximum integer value will be for this variable
    # which is the same as the number of categories
    N = max(df_train[col].max(),df_test[col].max())+1
    
    
    # this line of code does this: input_branch[:,idx]
    x = tf.gather(input_crossed, idx, axis=1)
    
    # now use an embedding to deal with integers as if they were one hot encoded
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name=col+'_embed')(x)
    
    # save these outputs to concatenate later
    crossed_outputs.append(x)
    

# now concatenate the outputs and add a fully connected layer
wide_branch = concatenate(crossed_outputs, name='wide_concat')

# reset this input branch
all_deep_branch_outputs = []

# CATEGORICAL DATA INPUT
input_cat = Input(shape=(X_train_cat.shape[1],), dtype='int64', name='categorical_input')
for idx,col in enumerate(categorical_headers_ints):
    
    # track what the maximum integer value will be for this variable
    # which is the same as the number of categories
    N = max(df_train[col].max(),df_test[col].max())+1
    
    # this line of code does this: input_branch[:,idx]
    x = tf.gather(input_cat, idx, axis=1)
    
    # now use an embedding to deal with integers as if they were one hot encoded
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name=col+'_embed')(x)
    
    # save these outputs to concatenate later
    all_deep_branch_outputs.append(x)
    
# NUMERIC DATA INPUT
# create dense input branch for numeric
input_num = Input(shape=(X_train_num.shape[1],), name='numeric')
x_dense = Dense(units=22, activation='relu',name='num_1')(input_num)
    
all_deep_branch_outputs.append(x_dense)


# merge the deep branches together
deep_branch = concatenate(all_deep_branch_outputs,name='concat_embeds')
deep_branch = Dense(units=50,activation='relu', name='deep1')(deep_branch)
deep_branch = Dense(units=25,activation='relu', name='deep2')(deep_branch)
deep_branch = Dense(units=10,activation='relu', name='deep3')(deep_branch)
    
# merge the deep and wide branch
final_branch = concatenate([wide_branch, deep_branch],
                           name='concat_deep_wide')
final_branch = Dense(units=1,activation='sigmoid',
                     name='combined')(final_branch)

model = Model(inputs=[input_crossed,input_cat,input_num], 
              outputs=final_branch)

# %%
# you will need to install pydot properly on your machine to get this running
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
# you will need to install pydot properly on your machine to get this running
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)
model.summary()
# Out:
# Model: "functional_19"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# categorical_input (InputLayer)  [(None, 8)]          0
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_52 (Tensor [(None,)]            0           categorical_input[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_53 (Tensor [(None,)]            0           categorical_input[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_54 (Tensor [(None,)]            0           categorical_input[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_55 (Tensor [(None,)]            0           categorical_input[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_56 (Tensor [(None,)]            0           categorical_input[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_57 (Tensor [(None,)]            0           categorical_input[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_58 (Tensor [(None,)]            0           categorical_input[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_59 (Tensor [(None,)]            0           categorical_input[0][0]
# __________________________________________________________________________________________________
# numeric (InputLayer)            [(None, 4)]          0
# __________________________________________________________________________________________________
# workclass_int_embed (Embedding) (None, 2)            14          tf_op_layer_GatherV2_52[0][0]
# __________________________________________________________________________________________________
# education_int_embed (Embedding) (None, 4)            64          tf_op_layer_GatherV2_53[0][0]
# __________________________________________________________________________________________________
# marital_status_int_embed (Embed (None, 2)            14          tf_op_layer_GatherV2_54[0][0]
# __________________________________________________________________________________________________
# occupation_int_embed (Embedding (None, 3)            42          tf_op_layer_GatherV2_55[0][0]
# __________________________________________________________________________________________________
# relationship_int_embed (Embeddi (None, 2)            12          tf_op_layer_GatherV2_56[0][0]
# __________________________________________________________________________________________________
# race_int_embed (Embedding)      (None, 2)            10          tf_op_layer_GatherV2_57[0][0]
# __________________________________________________________________________________________________
# sex_int_embed (Embedding)       (None, 1)            2           tf_op_layer_GatherV2_58[0][0]
# __________________________________________________________________________________________________
# country_int_embed (Embedding)   (None, 6)            246         tf_op_layer_GatherV2_59[0][0]
# __________________________________________________________________________________________________
# num_1 (Dense)                   (None, 22)           110         numeric[0][0]
# __________________________________________________________________________________________________
# wide_inputs (InputLayer)        [(None, 3)]          0
# __________________________________________________________________________________________________
# concat_embeds (Concatenate)     (None, 44)           0           workclass_int_embed[0][0]
#                                                                  education_int_embed[0][0]
#                                                                  marital_status_int_embed[0][0]
#                                                                  occupation_int_embed[0][0]
#                                                                  relationship_int_embed[0][0]
#                                                                  race_int_embed[0][0]
#                                                                  sex_int_embed[0][0]
#                                                                  country_int_embed[0][0]
#                                                                  num_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_49 (Tensor [(None,)]            0           wide_inputs[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_50 (Tensor [(None,)]            0           wide_inputs[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherV2_51 (Tensor [(None,)]            0           wide_inputs[0][0]
# __________________________________________________________________________________________________
# deep1 (Dense)                   (None, 50)           2250        concat_embeds[0][0]
# __________________________________________________________________________________________________
# sex_education_occupation_embed  (None, 19)           7144        tf_op_layer_GatherV2_49[0][0]
# __________________________________________________________________________________________________
# workclass_occupation_embed (Emb (None, 9)            747         tf_op_layer_GatherV2_50[0][0]
# __________________________________________________________________________________________________
# occupation_race_embed (Embeddin (None, 8)            544         tf_op_layer_GatherV2_51[0][0]
# __________________________________________________________________________________________________
# deep2 (Dense)                   (None, 25)           1275        deep1[0][0]
# __________________________________________________________________________________________________
# wide_concat (Concatenate)       (None, 36)           0           sex_education_occupation_embed[0]
#                                                                  workclass_occupation_embed[0][0]
#                                                                  occupation_race_embed[0][0]
# __________________________________________________________________________________________________
# deep3 (Dense)                   (None, 10)           260         deep2[0][0]
# __________________________________________________________________________________________________
# concat_deep_wide (Concatenate)  (None, 46)           0           wide_concat[0][0]
#                                                                  deep3[0][0]
# __________________________________________________________________________________________________
# combined (Dense)                (None, 1)            47          concat_deep_wide[0][0]
# ==================================================================================================
# Total params: 12,781
# Trainable params: 12,781
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
X_train_crossed
# Out:
# array([[292,  62,   4],
#        [295,  52,  17],
#        [320,  29,  27],
#        ...,
#        [130,  25,   4],
#        [315,  25,   4],
#        [132,  40,  17]])

# %%
# %%time

model.compile(optimizer='adagrad',
              loss='mean_squared_error',
              metrics=['accuracy'])

# lets also add the history variable to see how we are doing
# and lets add a validation set to keep track of our progress
history = model.fit([X_train_crossed,X_train_cat,X_train_num],
                    y_train, 
                    epochs=50, 
                    batch_size=32, 
                    verbose=1, 
                    validation_data = ([X_test_crossed,X_test_cat,X_test_num],y_test))
# Out:
# Epoch 1/50
# 943/943 [==============================] - 1s 1ms/step - loss: 0.1406 - accuracy: 0.7915 - val_loss: 0.1396 - val_accuracy: 0.7956
# Epoch 2/50
# 943/943 [==============================] - 1s 934us/step - loss: 0.1382 - accuracy: 0.7976 - val_loss: 0.1372 - val_accuracy: 0.8005
# Epoch 3/50
# 943/943 [==============================] - 1s 930us/step - loss: 0.1359 - accuracy: 0.8025 - val_loss: 0.1350 - val_accuracy: 0.8049
# Epoch 4/50
# 943/943 [==============================] - 1s 928us/step - loss: 0.1337 - accuracy: 0.8068 - val_loss: 0.1329 - val_accuracy: 0.8102
# Epoch 5/50
# 943/943 [==============================] - 1s 928us/step - loss: 0.1317 - accuracy: 0.8117 - val_loss: 0.1308 - val_accuracy: 0.8138
# Epoch 6/50
# 943/943 [==============================] - 1s 926us/step - loss: 0.1297 - accuracy: 0.8153 - val_loss: 0.1289 - val_accuracy: 0.8173
# Epoch 7/50
# 943/943 [==============================] - 1s 924us/step - loss: 0.1280 - accuracy: 0.8184 - val_loss: 0.1272 - val_accuracy: 0.8192
# Epoch 8/50
# 943/943 [==============================] - 1s 931us/step - loss: 0.1264 - accuracy: 0.8231 - val_loss: 0.1256 - val_accuracy: 0.8227
# Epoch 9/50
# 943/943 [==============================] - 1s 932us/step - loss: 0.1249 - accuracy: 0.8263 - val_loss: 0.1242 - val_accuracy: 0.8252
# Epoch 10/50
# 943/943 [==============================] - 1s 930us/step - loss: 0.1236 - accuracy: 0.8279 - val_loss: 0.1229 - val_accuracy: 0.8273
# Epoch 11/50
# 943/943 [==============================] - 1s 931us/step - loss: 0.1225 - accuracy: 0.8296 - val_loss: 0.1218 - val_accuracy: 0.8299
# Epoch 12/50
# 943/943 [==============================] - 1s 922us/step - loss: 0.1214 - accuracy: 0.8315 - val_loss: 0.1207 - val_accuracy: 0.8322
# Epoch 13/50
# 943/943 [==============================] - 1s 932us/step - loss: 0.1205 - accuracy: 0.8339 - val_loss: 0.1198 - val_accuracy: 0.8345
# Epoch 14/50
# 943/943 [==============================] - 1s 929us/step - loss: 0.1196 - accuracy: 0.8355 - val_loss: 0.1189 - val_accuracy: 0.8365
# Epoch 15/50
# 943/943 [==============================] - 1s 924us/step - loss: 0.1188 - accuracy: 0.8366 - val_loss: 0.1181 - val_accuracy: 0.8379
# Epoch 16/50
# 943/943 [==============================] - 1s 984us/step - loss: 0.1181 - accuracy: 0.8380 - val_loss: 0.1174 - val_accuracy: 0.8392
# Epoch 17/50
# 943/943 [==============================] - 1s 969us/step - loss: 0.1174 - accuracy: 0.8387 - val_loss: 0.1167 - val_accuracy: 0.8403
# Epoch 18/50
# 943/943 [==============================] - 1s 993us/step - loss: 0.1168 - accuracy: 0.8399 - val_loss: 0.1161 - val_accuracy: 0.8412
# Epoch 19/50
# 943/943 [==============================] - 1s 952us/step - loss: 0.1162 - accuracy: 0.8407 - val_loss: 0.1156 - val_accuracy: 0.8428
# Epoch 20/50
# 943/943 [==============================] - 1s 927us/step - loss: 0.1157 - accuracy: 0.8417 - val_loss: 0.1150 - val_accuracy: 0.8428
# Epoch 21/50
# 943/943 [==============================] - 1s 934us/step - loss: 0.1152 - accuracy: 0.8420 - val_loss: 0.1145 - val_accuracy: 0.8433
# Epoch 22/50
# 943/943 [==============================] - 1s 927us/step - loss: 0.1147 - accuracy: 0.8427 - val_loss: 0.1140 - val_accuracy: 0.8438
# Epoch 23/50
# 943/943 [==============================] - 1s 928us/step - loss: 0.1142 - accuracy: 0.8431 - val_loss: 0.1136 - val_accuracy: 0.8442
# Epoch 24/50
# 943/943 [==============================] - 1s 932us/step - loss: 0.1138 - accuracy: 0.8437 - val_loss: 0.1132 - val_accuracy: 0.8451
# Epoch 25/50
# 943/943 [==============================] - 1s 932us/step - loss: 0.1134 - accuracy: 0.8437 - val_loss: 0.1128 - val_accuracy: 0.8452
# Epoch 26/50
# 943/943 [==============================] - 1s 928us/step - loss: 0.1130 - accuracy: 0.8444 - val_loss: 0.1124 - val_accuracy: 0.8454
# Epoch 27/50
# 943/943 [==============================] - 1s 928us/step - loss: 0.1126 - accuracy: 0.8447 - val_loss: 0.1120 - val_accuracy: 0.8455
# Epoch 28/50
# 943/943 [==============================] - 1s 931us/step - loss: 0.1123 - accuracy: 0.8450 - val_loss: 0.1117 - val_accuracy: 0.8461
# Epoch 29/50
# 943/943 [==============================] - 1s 930us/step - loss: 0.1120 - accuracy: 0.8450 - val_loss: 0.1114 - val_accuracy: 0.8461
# Epoch 30/50
# 943/943 [==============================] - 1s 931us/step - loss: 0.1116 - accuracy: 0.8458 - val_loss: 0.1111 - val_accuracy: 0.8471
# Epoch 31/50
# 943/943 [==============================] - 1s 928us/step - loss: 0.1113 - accuracy: 0.8457 - val_loss: 0.1108 - val_accuracy: 0.8473
# Epoch 32/50
# 943/943 [==============================] - 1s 971us/step - loss: 0.1110 - accuracy: 0.8454 - val_loss: 0.1105 - val_accuracy: 0.8477
# Epoch 33/50
# 943/943 [==============================] - 1s 929us/step - loss: 0.1108 - accuracy: 0.8454 - val_loss: 0.1102 - val_accuracy: 0.8479
# Epoch 34/50
# 943/943 [==============================] - 1s 927us/step - loss: 0.1105 - accuracy: 0.8455 - val_loss: 0.1100 - val_accuracy: 0.8479
# Epoch 35/50
# 943/943 [==============================] - 1s 931us/step - loss: 0.1102 - accuracy: 0.8458 - val_loss: 0.1097 - val_accuracy: 0.8480
# Epoch 36/50
# 943/943 [==============================] - 1s 952us/step - loss: 0.1100 - accuracy: 0.8459 - val_loss: 0.1095 - val_accuracy: 0.8483
# Epoch 37/50
# 943/943 [==============================] - 1s 989us/step - loss: 0.1098 - accuracy: 0.8464 - val_loss: 0.1093 - val_accuracy: 0.8487
# Epoch 38/50
# 943/943 [==============================] - 1s 1ms/step - loss: 0.1095 - accuracy: 0.8461 - val_loss: 0.1090 - val_accuracy: 0.8487
# Epoch 39/50
# 943/943 [==============================] - 1s 1ms/step - loss: 0.1093 - accuracy: 0.8465 - val_loss: 0.1088 - val_accuracy: 0.8494
# Epoch 40/50
# 943/943 [==============================] - 1s 930us/step - loss: 0.1091 - accuracy: 0.8466 - val_loss: 0.1086 - val_accuracy: 0.8498
# Epoch 41/50
# 943/943 [==============================] - 1s 927us/step - loss: 0.1089 - accuracy: 0.8471 - val_loss: 0.1085 - val_accuracy: 0.8503
# Epoch 42/50
# 943/943 [==============================] - 1s 925us/step - loss: 0.1087 - accuracy: 0.8472 - val_loss: 0.1083 - val_accuracy: 0.8501
# Epoch 43/50
# 943/943 [==============================] - 1s 934us/step - loss: 0.1085 - accuracy: 0.8473 - val_loss: 0.1081 - val_accuracy: 0.8502
# Epoch 44/50
# 943/943 [==============================] - 1s 931us/step - loss: 0.1083 - accuracy: 0.8478 - val_loss: 0.1079 - val_accuracy: 0.8503
# Epoch 45/50
# 943/943 [==============================] - 1s 931us/step - loss: 0.1082 - accuracy: 0.8475 - val_loss: 0.1078 - val_accuracy: 0.8503
# Epoch 46/50
# 943/943 [==============================] - 1s 917us/step - loss: 0.1080 - accuracy: 0.8478 - val_loss: 0.1076 - val_accuracy: 0.8503
# Epoch 47/50
# 943/943 [==============================] - 1s 932us/step - loss: 0.1078 - accuracy: 0.8479 - val_loss: 0.1075 - val_accuracy: 0.8501
# Epoch 48/50
# 943/943 [==============================] - 1s 948us/step - loss: 0.1077 - accuracy: 0.8479 - val_loss: 0.1073 - val_accuracy: 0.8506
# Epoch 49/50
# 943/943 [==============================] - 1s 936us/step - loss: 0.1075 - accuracy: 0.8482 - val_loss: 0.1072 - val_accuracy: 0.8506
# Epoch 50/50
# 943/943 [==============================] - 1s 921us/step - loss: 0.1074 - accuracy: 0.8484 - val_loss: 0.1070 - val_accuracy: 0.8510
# Wall time: 45.6 s

# %%
yhat = np.round(model.predict([X_test_crossed,X_test_cat,X_test_num]))
print(mt.confusion_matrix(y_test,yhat))
print(mt.classification_report(y_test,yhat))
# Out:
# [[10617   743]
#  [ 1501  2199]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90     11360
#            1       0.75      0.59      0.66      3700
#
#     accuracy                           0.85     15060
#    macro avg       0.81      0.76      0.78     15060
# weighted avg       0.84      0.85      0.84     15060

# %%
from matplotlib import pyplot as plt

# %matplotlib inline

plt.figure(figsize=(10,4))
plt.subplot(2,2,1)
plt.plot(history.history['accuracy'])

plt.ylabel('Accuracy %')
plt.title('Training')
plt.subplot(2,2,2)
plt.plot(history.history['val_accuracy'])
plt.title('Validation')

plt.subplot(2,2,3)
plt.plot(history.history['loss'])
plt.ylabel('Training Loss')
plt.xlabel('epochs')

plt.subplot(2,2,4)
plt.plot(history.history['val_loss'])
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# # Making Generalization Better
# In what ways might we try to make the model found generalize more concretely?
#
# **Self Test:** What is the best method to make the results better?
# - A. Add Dropout to deep network
# - B. Add Dropout to wide network
# - C. Perturb the Categorical Data during Training (augmentation)
# - D. Add L2 regularization to different layer's weights
